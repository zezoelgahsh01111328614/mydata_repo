# %%
import pandas as pd
from glob import glob

# %% [markdown]
# # using glob method to select all files from a bath

# %%
all_monthes = sorted(glob(r'C:\Users\Options\Desktop\SalesAnalysis\Sales_Data\Sales_*_*.csv'))
all_monthes
# Out:
# ['C:\\Users\\Options\\Desktop\\SalesAnalysis\\Sales_Data\\Sales_April_2019.csv',
#  'C:\\Users\\Options\\Desktop\\SalesAnalysis\\Sales_Data\\Sales_August_2019.csv',
#  'C:\\Users\\Options\\Desktop\\SalesAnalysis\\Sales_Data\\Sales_December_2019.csv',
#  'C:\\Users\\Options\\Desktop\\SalesAnalysis\\Sales_Data\\Sales_February_2019.csv',
#  'C:\\Users\\Options\\Desktop\\SalesAnalysis\\Sales_Data\\Sales_January_2019.csv',
#  'C:\\Users\\Options\\Desktop\\SalesAnalysis\\Sales_Data\\Sales_July_2019.csv',
#  'C:\\Users\\Options\\Desktop\\SalesAnalysis\\Sales_Data\\Sales_June_2019.csv',
#  'C:\\Users\\Options\\Desktop\\SalesAnalysis\\Sales_Data\\Sales_March_2019.csv',
#  'C:\\Users\\Options\\Desktop\\SalesAnalysis\\Sales_Data\\Sales_May_2019.csv',
#  'C:\\Users\\Options\\Desktop\\SalesAnalysis\\Sales_Data\\Sales_November_2019.csv',
#  'C:\\Users\\Options\\Desktop\\SalesAnalysis\\Sales_Data\\Sales_October_2019.csv',
# ...

# %% [markdown]
# # concat all files in one variable

# %%
all_months_data =pd.concat((pd.read_csv(file).assign(filename = file)
        for file in all_monthes) ,ignore_index = True)

# %%
all_months_data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address  \
# ...
